# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# import seaborn as sns
print("Environment Ready!")
# Out:
# Environment Ready!

# %%
df = pd.read_csv(r"C:\Users\muska\OneDrive\Documents\Data-Analyst-Portfolio\Ecommerce-Sales-Analysis\dataset\Sample - Superstore.csv")

# %%
df.head()
# Out:
#   CSGroup Profit Ratio         Category             City        Country  \
# 0     A&B          16%        Furniture        Henderson  United States
# 1     CEF          30%        Furniture        Henderson  United States
# 2    Rest          47%  Office Supplies      Los Angeles  United States
# 3    Rest         -40%        Furniture  Fort Lauderdale  United States
# 4    Rest          11%  Office Supplies  Fort Lauderdale  United States
#
#      Customer Name Discount  Number of Records  Order Date        Order ID  \
# 0      Claire Gute       0%                  1  08-11-2017  CA-2017-152156
# 1      Claire Gute       0%                  1  08-11-2017  CA-2017-152156
# 2  Darrin Van Huff       0%                  1  12-06-2017  CA-2017-138688
# 3   Sean O'Donnell      45%                  1  11-10-2016  US-2016-108966
# 4   Sean O'Donnell      20%                  1  11-10-2016  US-2016-108966
#
#    ...   Ship Date       Ship Mode       State Sub-Category (group) 2  \
# ...

# %%
df.tail()
# Out:
#      CSGroup Profit Ratio    Category           City        Country  \
# 9989    Rest          10%  Technology    Los Angeles  United States
# 9990    Rest          11%  Technology    Los Angeles  United States
# 9991    Rest           8%  Technology  Santa Barbara  United States
# 9992    Rest         -80%  Technology           Yuma  United States
# 9993    Rest        -133%  Technology     Louisville  United States
#
#        Customer Name Discount  Number of Records  Order Date        Order ID  \
# 9989      Ben Ferrer      20%                  1  24-12-2015  US-2015-138247
# 9990      Ben Ferrer      20%                  1  12-07-2015  CA-2015-110184
# 9991   Maria Etezadi      20%                  1  06-06-2017  CA-2017-160717
# 9992     Gary Hansen      70%                  1  16-10-2018  CA-2018-159282
# 9993  Sharelle Roach      70%                  1  17-04-2018  CA-2018-134845
#
#       ...   Ship Date       Ship Mode       State Sub-Category (group) 2  \
# ...

# %%
df.head()
# Out:
#   CSGroup Profit Ratio         Category             City        Country  \
# 0     A&B          16%        Furniture        Henderson  United States
# 1     CEF          30%        Furniture        Henderson  United States
# 2    Rest          47%  Office Supplies      Los Angeles  United States
# 3    Rest         -40%        Furniture  Fort Lauderdale  United States
# 4    Rest          11%  Office Supplies  Fort Lauderdale  United States
#
#      Customer Name Discount  Number of Records  Order Date        Order ID  \
# 0      Claire Gute       0%                  1  08-11-2017  CA-2017-152156
# 1      Claire Gute       0%                  1  08-11-2017  CA-2017-152156
# 2  Darrin Van Huff       0%                  1  12-06-2017  CA-2017-138688
# 3   Sean O'Donnell      45%                  1  11-10-2016  US-2016-108966
# 4   Sean O'Donnell      20%                  1  11-10-2016  US-2016-108966
#
#    ...   Ship Date       Ship Mode       State Sub-Category (group) 2  \
# ...

# %%
df.shape
# Out:
# (9994, 29)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CSGroup                 9994 non-null   str
#  1   Profit Ratio            9994 non-null   str
#  2   Category                9994 non-null   str
#  3   City                    9994 non-null   str
#  4   Country                 9994 non-null   str
#  5   Customer Name           9994 non-null   str
#  6   Discount                9994 non-null   str
#  7   Number of Records       9994 non-null   int64
#  8   Order Date              9994 non-null   str
#  9   Order ID                9994 non-null   str
#  10  Postal Code             9983 non-null   float64
#  11  Manufacturer            9994 non-null   str
#  12  Product Name            9994 non-null   str
#  13  Profit                  9994 non-null   str
#  14  Quantity                9994 non-null   int64
# ...

# %%
df.columns
# Out:
# Index(['CSGroup', 'Profit Ratio', 'Category', 'City', 'Country',
#        'Customer Name', 'Discount', 'Number of Records', 'Order Date',
#        'Order ID', 'Postal Code', 'Manufacturer', 'Product Name', 'Profit',
#        'Quantity', 'Region', 'SC group', 'Sales', 'Segment', 'Ship Date',
#        'Ship Mode', 'State', 'Sub-Category (group) 2',
#        'Sub-Category (group) 3', 'Sub-Category (group) 4',
#        'Sub-Category (group) 5', 'Sub-Category (group) 6',
#        'Sub-Category (group)', 'Sub-Category'],
#       dtype='str')

# %%
df.isnull()
# Out:
#       CSGroup  Profit Ratio  Category   City  Country  Customer Name  \
# 0       False         False     False  False    False          False
# 1       False         False     False  False    False          False
# 2       False         False     False  False    False          False
# 3       False         False     False  False    False          False
# 4       False         False     False  False    False          False
# ...       ...           ...       ...    ...      ...            ...
# 9989    False         False     False  False    False          False
# 9990    False         False     False  False    False          False
# 9991    False         False     False  False    False          False
# 9992    False         False     False  False    False          False
# 9993    False         False     False  False    False          False
#
#       Discount  Number of Records  Order Date  Order ID  ...  Ship Date  \
# ...

# %%
df.isnull().sum()
# Out:
# CSGroup                    0
# Profit Ratio               0
# Category                   0
# City                       0
# Country                    0
# Customer Name              0
# Discount                   0
# Number of Records          0
# Order Date                 0
# Order ID                   0
# Postal Code               11
# Manufacturer               0
# Product Name               0
# Profit                     0
# Quantity                   0
# Region                     0
# SC group                   0
# Sales                      0
# Segment                    0
# Ship Date                  0
# Ship Mode                  0
# State                      0
# Sub-Category (group) 2     0
# Sub-Category (group) 3     0
# Sub-Category (group) 4     0
# Sub-Category (group) 5     0
# Sub-Category (group) 6     0
# Sub-Category (group)       0
# Sub-Category               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (9993, 29)

# %%
df.dtypes
# Out:
# CSGroup                       str
# Profit Ratio                  str
# Category                      str
# City                          str
# Country                       str
# Customer Name                 str
# Discount                      str
# Number of Records           int64
# Order Date                    str
# Order ID                      str
# Postal Code               float64
# Manufacturer                  str
# Product Name                  str
# Profit                        str
# Quantity                    int64
# Region                        str
# SC group                      str
# Sales                         str
# Segment                       str
# Ship Date                     str
# Ship Mode                     str
# State                         str
# Sub-Category (group) 2        str
# Sub-Category (group) 3        str
# Sub-Category (group) 4        str
# Sub-Category (group) 5        str
# Sub-Category (group) 6        str
# ...

# %%
df["Sales"].head()
# Out:
# 0    $262
# 1    $732
# 2     $15
# 3    $958
# 4     $22
# Name: Sales, dtype: str

# %%
df["Profit"].head()
# Out:
# 0      $42
# 1     $220
# 2       $7
# 3    -$383
# 4       $3
# Name: Profit, dtype: str

# %%
df["Profit Ratio"].head()
# Out:
# 0     16%
# 1     30%
# 2     47%
# 3    -40%
# 4     11%
# Name: Profit Ratio, dtype: str

# %%
df["Discount"].head()
# Out:
# 0     0%
# 1     0%
# 2     0%
# 3    45%
# 4    20%
# Name: Discount, dtype: str

# %%
df["Sales"].sample(10)
# Out:
# 3415     $76
# 4480     $49
# 6717      $5
# 4000     $64
# 2007     $10
# 4547     $39
# 1637    $450
# 4853     $53
# 3149      $4
# 7280      $5
# Name: Sales, dtype: str

# %%
df["Sales"] = (
    df["Sales"]
    .str.replace("$", "", regex=False)
    .str.replace(",", "", regex=False)
)

df["Sales"] = df["Sales"].astype(float)

# %%
df["Profit"] = (
    df["Profit"]
    .str.replace("-$", "-", regex=False)
    .str.replace("$", "", regex=False)
    .str.replace(",", "", regex=False)
)

df["Profit"] = df["Profit"].astype(float)

# %%
df[["Sales", "Profit"]].dtypes
# Out:
# Sales     float64
# Profit    float64
# dtype: object

# %%
df["Discount"] = (
    df["Discount"]
    .str.replace("%", "", regex=False)
    .astype(float)
)

# %%
df["Profit Ratio"] = (
    df["Profit Ratio"]
    .str.replace("%", "", regex=False)
    .astype(float)
)

# %%
df["Discount"].dtype
df["Profit Ratio"].dtype
# Out:
# dtype('float64')

# %%
df["Order Date"].head()
# Out:
# 0    08-11-2017
# 1    08-11-2017
# 2    12-06-2017
# 3    11-10-2016
# 4    11-10-2016
# Name: Order Date, dtype: str

# %%
df["Ship Date"].head()
# Out:
# 0    11-11-2017
# 1    11-11-2017
# 2    16-06-2017
# 3    18-10-2016
# 4    18-10-2016
# Name: Ship Date, dtype: str

# %%
df["Order Date"].head()
# Out:
# 0    08-11-2017
# 1    08-11-2017
# 2    12-06-2017
# 3    11-10-2016
# 4    11-10-2016
# Name: Order Date, dtype: str

# %%
df["Order Date"] = pd.to_datetime(
    df["Order Date"],
    format="%d-%m-%Y"
)

df["Ship Date"] = pd.to_datetime(
    df["Ship Date"],
    format="%d-%m-%Y"
)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 9993 entries, 0 to 9993
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CSGroup                 9993 non-null   str
#  1   Profit Ratio            9993 non-null   float64
#  2   Category                9993 non-null   str
#  3   City                    9993 non-null   str
#  4   Country                 9993 non-null   str
#  5   Customer Name           9993 non-null   str
#  6   Discount                9993 non-null   float64
#  7   Number of Records       9993 non-null   int64
#  8   Order Date              9993 non-null   datetime64[us]
#  9   Order ID                9993 non-null   str
#  10  Postal Code             9982 non-null   float64
#  11  Manufacturer            9993 non-null   str
#  12  Product Name            9993 non-null   str
#  13  Profit                  9993 non-null   float64
#  14  Quantity                9993 non-null   int64
# ...

# %%
df.describe()
# Out:
#        Profit Ratio     Discount  Number of Records  \
# count   9993.000000  9993.000000             9993.0
# mean      12.054838    15.618833                1.0
# min     -275.000000     0.000000                1.0
# 25%        7.000000     0.000000                1.0
# 50%       27.000000    20.000000                1.0
# 75%       36.000000    20.000000                1.0
# max       50.000000    80.000000                1.0
# std       46.694354    20.645729                0.0
#
#                        Order Date   Postal Code       Profit     Quantity  \
# count                        9993   9982.000000  9993.000000  9993.000000
# mean   2017-04-30 07:03:30.747523  55246.437087    28.655959     3.789753
# min           2015-01-03 00:00:00   1040.000000 -6600.000000     1.000000
# 25%           2016-05-23 00:00:00  23223.000000     2.000000     2.000000
# 50%           2017-06-26 00:00:00  57103.000000     9.000000     3.000000
# ...

# %%
df.to_csv(r"C:\Users\muska\OneDrive\Documents\Data-Analyst-Portfolio\Ecommerce-Sales-Analysis\cleaned_data\cleaned_superset.csv",index=False)
